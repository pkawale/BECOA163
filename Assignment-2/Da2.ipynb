# %% [markdown]
# # Data Analytics Assignment No. 2
# #PimaIndians Diabetes dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
url='../Desktop/pima_indians_diabetes.csv'

# %%
df=pd.read_csv(url,header=0)

# %%
headers=['no_of_times_pregnant','glucose','bloodpressure','SkinThickness','Insulin','BMI','DiabetesPedigree','Age','OutCome']

# %%
df.columns=headers

# %%
print(df)
# Out:
#      no_of_times_pregnant  glucose  bloodpressure  SkinThickness  Insulin  \
# 0                       1       85             66             29        0
# 1                       8      183             64              0        0
# 2                       1       89             66             23       94
# 3                       0      137             40             35      168
# 4                       5      116             74              0        0
# 5                       3       78             50             32       88
# 6                      10      115              0              0        0
# 7                       2      197             70             45      543
# 8                       8      125             96              0        0
# 9                       4      110             92              0        0
# 10                     10      168             74              0        0
# 11                     10      139             80              0        0
# ...

# %%
[rows,columns]=df.shape

# %%
print(df.shape)
# Out:
# (767, 9)

# %%
print("Number of rows:"+str(df.shape[0]))
print("Number of columns:"+str(df.shape[1]))
# Out:
# Number of rows:767
# Number of columns:9

# %%
df.head(10)
# Out:
#    no_of_times_pregnant  glucose  bloodpressure  SkinThickness  Insulin   BMI  \
# 0                     1       85             66             29        0  26.6
# 1                     8      183             64              0        0  23.3
# 2                     1       89             66             23       94  28.1
# 3                     0      137             40             35      168  43.1
# 4                     5      116             74              0        0  25.6
# 5                     3       78             50             32       88  31.0
# 6                    10      115              0              0        0  35.3
# 7                     2      197             70             45      543  30.5
# 8                     8      125             96              0        0   0.0
# 9                     4      110             92              0        0  37.6
#
#    DiabetesPedigree  Age  OutCome
# 0             0.351   31        0
# 1             0.672   32        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
# no_of_times_pregnant    767 non-null int64
# glucose                 767 non-null int64
# bloodpressure           767 non-null int64
# SkinThickness           767 non-null int64
# Insulin                 767 non-null int64
# BMI                     767 non-null float64
# DiabetesPedigree        767 non-null float64
# Age                     767 non-null int64
# OutCome                 767 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.0 KB

# %%
df.describe()
# Out:
#        no_of_times_pregnant     glucose  bloodpressure  SkinThickness  \
# count            767.000000  767.000000     767.000000     767.000000
# mean               3.842243  120.859192      69.101695      20.517601
# std                3.370877   31.978468      19.368155      15.954059
# min                0.000000    0.000000       0.000000       0.000000
# 25%                1.000000   99.000000      62.000000       0.000000
# 50%                3.000000  117.000000      72.000000      23.000000
# 75%                6.000000  140.000000      80.000000      32.000000
# max               17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigree         Age     OutCome
# count  767.000000  767.000000        767.000000  767.000000  767.000000
# mean    79.903520   31.990482          0.471674   33.219035    0.348110
# std    115.283105    7.889091          0.331497   11.752296    0.476682
# ...

# %%
df.dtypes
# Out:
# no_of_times_pregnant      int64
# glucose                   int64
# bloodpressure             int64
# SkinThickness             int64
# Insulin                   int64
# BMI                     float64
# DiabetesPedigree        float64
# Age                       int64
# OutCome                   int64
# dtype: object

# %%
df.describe()
# Out:
#        no_of_times_pregnant     glucose  bloodpressure  SkinThickness  \
# count            767.000000  767.000000     767.000000     767.000000
# mean               3.842243  120.859192      69.101695      20.517601
# std                3.370877   31.978468      19.368155      15.954059
# min                0.000000    0.000000       0.000000       0.000000
# 25%                1.000000   99.000000      62.000000       0.000000
# 50%                3.000000  117.000000      72.000000      23.000000
# 75%                6.000000  140.000000      80.000000      32.000000
# max               17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigree         Age     OutCome
# count  767.000000  767.000000        767.000000  767.000000  767.000000
# mean    79.903520   31.990482          0.471674   33.219035    0.348110
# std    115.283105    7.889091          0.331497   11.752296    0.476682
# ...

# %%
df.describe(include="all")
# Out:
#        no_of_times_pregnant     glucose  bloodpressure  SkinThickness  \
# count            767.000000  767.000000     767.000000     767.000000
# mean               3.842243  120.859192      69.101695      20.517601
# std                3.370877   31.978468      19.368155      15.954059
# min                0.000000    0.000000       0.000000       0.000000
# 25%                1.000000   99.000000      62.000000       0.000000
# 50%                3.000000  117.000000      72.000000      23.000000
# 75%                6.000000  140.000000      80.000000      32.000000
# max               17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigree         Age     OutCome
# count  767.000000  767.000000        767.000000  767.000000  767.000000
# mean    79.903520   31.990482          0.471674   33.219035    0.348110
# std    115.283105    7.889091          0.331497   11.752296    0.476682
# ...

# %%
df.to_csv("/home/administrator/op_samplenaive.csv")

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f068894fcc0>,
# ...
#       dtype=object)

# %%
df.boxplot()

# %%
df.mode()
# Out:
#    no_of_times_pregnant  glucose  bloodpressure  SkinThickness  Insulin   BMI  \
# 0                   1.0       99           70.0            0.0      0.0  32.0
# 1                   NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigree   Age  OutCome
# 0             0.254  22.0      0.0
# 1             0.258   NaN      NaN

# %%
df.median()
# Out:
# no_of_times_pregnant      3.000
# glucose                 117.000
# bloodpressure            72.000
# SkinThickness            23.000
# Insulin                  32.000
# BMI                      32.000
# DiabetesPedigree          0.371
# Age                      29.000
# OutCome                   0.000
# dtype: float64

# %%
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0688540898>,
# ...
#       dtype=object)

# %%
sns.pairplot(df,hue="OutCome")
